# %%
import numpy as np
import pandas as pd
from utils import *
import csv

# %%
df = pd.read_csv('DataSuture.csv')

# %%
vocab = set()

for sentence in df.desc:
    sentence = textPrep(sentence)
    vocab.update(textSeperate(sentence))

for sentence in df.wordId:
    if not (pd.isnull(sentence)):
        sentence = textPrep(sentence)
        vocab.update(textSeperate(sentence))
    
vocab = sorted(vocab)

# %%
df.head()
# Out:
#                                                 desc   wordId
# 0      Chỉ phẫu thuật  TICRON  (36 tép / hộp)  88...   Ticron
# 1    CHỈ  KHÂU PHẪU THUẬT TỰ TIÊU SINH HỌC  PLAIN...    Plain
# 2    CHỈ  KHÂU PHẪU THUẬT TỰ TIÊU SINH HỌC  PLAIN...    Plain
# 3    CHỈ  KHÂU PHẪU THUẬT TỰ TIÊU SINH HỌC CHROMI...  Chromic
# 4    CHỈ  KHÂU PHẪU THUẬT TỰ TIÊU SINH HỌC CHROMI...  Chromic

# %%
df.desc = df.desc.apply(textPrep)
df.wordId = df.wordId.apply(textPrep)

# %%
df.head()
# Out:
#                                                 desc   wordId
# 0  chỉ phẫu thuật ticron 36 tép hộp 8886327141 mớ...   ticron
# 1  chỉ khâu phẫu thuật tự tiêu sinh học plain pre...    plain
# 2  chỉ khâu phẫu thuật tự tiêu sinh học plain pre...    plain
# 3  chỉ khâu phẫu thuật tự tiêu sinh học chromic p...  chromic
# 4  chỉ khâu phẫu thuật tự tiêu sinh học chromic p...  chromic

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import numpy as np

maxlen = 300

tokenizer = Tokenizer()
tokenizer.fit_on_texts(df.desc)
# Out:
# /home/huypham/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
tokenizer.word_docs
# Out:
# defaultdict(int,
#             {'sản': 2659,
#              'tép': 789,
#              'hộp': 5388,
#              'nhà': 1027,
#              'ticron': 99,
#              'xuất': 2632,
#              'năm': 3016,
#              'thuật': 11079,
#              '8886327141': 2,
#              'covidien': 696,
#              'mới': 10312,
#              '2015': 1305,
#              'chỉ': 11148,
#              '36': 1036,
#              'phẫu': 10541,
#              '100': 10308,
#              'usp': 1940,
#              '3': 3589,
#              '1': 3878,
#              '0': 7723,
#              'khâu': 4793,
#              'học': 155,
#              'tiêu': 4647,
#              'tự': 3001,
#              'premium': 102,
#              '5m': 59,
#              'plain': 185,
#              'sinh': 155,
#              '2': 4390,
#              'chromic': 252,
#              'hãng': 3393,
#              'cofibam': 67,
#              'brazil': 67,
#              '5': 2516,
#              '6': 1131,
#              '4': 1888,
#              'cơ': 101,
#              'vật': 187,
#              'ngày': 182,
#              'ar': 1,
#              'y': 1369,
#              'trong': 1512,
#              'trên': 1,
#              'tế': 1311,
#              'wire': 9,
#              'dài': 1338,
#              'byt': 160,
#              'fiber': 1,
#              'do': 105,
#              'gp': 164,
#              'ghép': 142,
#              'hàng': 8025,
#              '7200': 1,
#              'cấy': 59,
#              '30': 130,
#              'lâu': 21,
#              'liệu': 409,
#              'thề': 1,
#              'arthrex': 1,
#              'đơn': 311,
#              'bhd': 60,
#              'devices': 191,
#              'sợi': 1713,
#              '2014': 906,
#              'medical': 571,
#              'vigilenz': 348,
#              'sdn': 60,
#              '12': 3470,
#              'polyamide': 64,
#              'sx': 3561,
#              'b27cd240': 12,
#              'hsx': 781,
#              'brilon': 68,
#              'malaysia': 219,
#              'không': 2249,
#              'nsx': 1055,
#              'b37cd240': 17,
#              'b47cd190': 8,
#              'b57cd160': 7,
#              '75': 954,
#              'daclon': 354,
#              'cir': 1212,
#              'sử': 450,
#              'hạn': 859,
#              'ep': 1283,
#              'lô': 907,
#              'taper': 749,
#              '170102': 16,
#              'cm': 1570,
#              'nylon': 756,
#              'monofil': 250,
#              '2022': 347,
#              '2017': 725,
#              'mm': 1115,
#              'dụng': 543,
#              '26': 279,
#              'needle': 1196,
#              '01': 154,
#              '19': 115,
#              '8': 1504,
#              '04': 72,
#              '170407': 9,
#              'cut': 317,
#              '170505': 5,
#              '05': 142,
#              'circ': 77,
#              'spatuled': 55,
#              '10': 617,
#              '160801': 5,
#              '20': 233,
#              '08': 84,
#              '150m': 8,
#              '2021': 488,
#              'tá': 130,
#              'x': 447,
#              'surgery': 43,
#              'surgical': 1834,
#              'needled': 67,
#              'undyed': 115,
#              'batch': 35,
#              'cỡ': 216,
#              'ltd': 327,
#              'meril': 42,
#              '90': 230,
#              'tiệt': 1393,
#              'sterilized': 47,
#              'suture': 676,
#              'megasorb': 15,
#              'dyed': 33,
#              'số': 1400,
#              'pvt': 171,
#              'trùng': 4060,
#              'ib17002': 4,
#              'chiếc': 205,
#              'endo': 45,
#              '40mm': 293,
#              'ib16005': 2,
#              'ib17001': 8,
#              '70': 72,
#              '26mm': 442,
#              'ib16003': 5,
#              '22mm': 77,
#              'ib16002': 3,
#              '17mm': 81,
#              'loại': 3567,
#              'd': 855,
#              'ii': 240,
#              'surgipro': 209,
#              'vp709x': 12,
#              '75cm': 2772,
#              '2xv': 11,
#              'vp706x': 7,
#              '11': 133,
#              'needles': 106,
#              'm04ee06l45': 1,
#              'black': 389,
#              'nước': 40,
#              'độ': 139,
#              '135': 13,
#              'quality': 21,
#              'ấn': 139,
#              'ds': 58,
#              'phẩu': 570,
#              '12cái': 152,
#              'e27rh220': 1,
#              'e39rh260': 1,
#              '90cm': 1213,
#              'f47rh17w': 1,
#              'đen': 73,
#              'silk': 600,
#              '150808': 11,
#              'dùng': 2089,
#              '2016': 1621,
#              'màu': 118,
#              '2020': 480,
#              '37mm': 44,
#              'ct': 226,
#              'v': 301,
#              '606': 48,
#              'tb': 142,
#              'mỹ': 277,
#              'polysorb': 171,
#              'định': 28,
#              '5mm': 67,
#              'lưới': 268,
#              'để': 117,
#              'protack': 8,
#              'instrument': 14,
#              'cụ': 145,
#              'thoát': 142,
#              'vị': 147,
#              'cố': 24,
#              'mono': 69,
#              '11x6cm': 6,
#              'parietex': 24,
#              'mesh': 341,
#              'điều': 90,
#              'poly': 105,
#              'trị': 101,
#              'pháp': 10,
#              '15x10cm': 18,
#              'tổng': 2140,
#              'monocryl': 114,
#              'hợp': 2138,
#              'm2': 200,
#              'cái': 2371,
#              'vô': 2640,
#              'hiệu': 3519,
#              'product': 1806,
#              'w3207': 17,
#              'ps': 136,
#              '45cm': 613,
#              'code': 2812,
#              'ethicon': 2494,
#              'und': 395,
#              'prolene': 542,
#              'vb': 57,
#              'rb': 168,
#              'w8330': 11,
#              'm1': 274,
#              'blu': 437,
#              'hr40s': 103,
#              '36pcs': 839,
#              'c0068557': 14,
#              'm': 643,
#              'novosyn': 120,
#              'pac': 1174,
#              'violet': 598,
#              'b': 1370,
#              'braun': 1225,
#              'pdo': 63,
#              '12sợi': 11,
#              'angiotech': 6,
#              'model': 875,
#              '1012q': 1,
#              '2013': 5,
#              'ra': 13,
#              'quill': 5,
#              '1028q': 1,
#              '1065q': 1,
#              '1015q': 1,
#              'monoderm': 2,
#              'ya': 2,
#              '1022q': 1,
#              'nhãn': 909,
#              '0chỉ': 1,
#              'đi': 498,
#              '30cm': 178,
#              'smi': 552,
#              'trở': 482,
#              '2mm': 31,
#              'ag': 567,
#              '150': 91,
#              'tra': 11,
#              'kiểm': 11,
#              '1000yds': 6,
#              's30012': 4,
#              'lỗ': 11,
#              'kim': 1354,
#              'bằng': 87,
#              'mổ': 5,
#              'kí': 9,
#              'lot': 161,
#              '400yds': 2,
#              's30009': 2,
#              'cuộn': 389,
#              'set': 51,
#              's30016': 1,
#              '500yds': 1,
#              's30008': 4,
#              'a': 665,
#              'mổkí': 1,
#              '855yds': 2,
#              'in': 18,
#              'gói': 119,
#              'khổ': 27,
#              'miếng': 306,
#              'h1546': 4,
#              'closures': 2,
#              '64cm': 4,
#              '16': 85,
#              'tm': 83,
#              'steri': 27,
#              'nexcare': 5,
#              'strip': 27,
#              'băng': 41,
#              '3m': 10,
#              'dán': 43,
#              'thay': 39,
#              'đóng': 40,
#              'da': 603,
#              'skin': 17,
#              '50': 91,
#              'blend': 5,
#              'closure': 26,
#              'thùng': 13,
#              'tone': 5,
#              'dính': 36,
#              'b1551': 2,
#              'b1550': 1,
#              'b1557': 4,
#              'kích': 33,
#              '2in': 6,
#              '4in': 9,
#              'b1559': 2,
#              '18': 22,
#              'h1547': 1,
#              'r1542': 2,
#              '5in': 4,
#              'r1549': 3,
#              '25': 154,
#              'r1548': 5,
#              '54cm': 3,
#              '7cm': 3,
#              '16cm': 3,
#              'r1540': 4,
#              '32': 4,
#              'chủng': 1315,
#              'company': 8,
#              'r1541': 3,
#              '64': 4,
#              'r1546': 3,
#              'r1547': 5,
#              '27': 14,
#              '54': 4,
#              '7': 744,
#              '10cm': 17,
#              '2cm': 15,
#              '32cm': 1,
#              '8cm': 19,
#              '3in': 1,
#              '50miếng': 1,
#              '27cm': 1,
#              'khổ1': 2,
#              'keo': 58,
#              'có': 204,
#              'hd': 495,
#              '151201': 4,
#              'h9051512': 3,
#              'size': 191,
#              'mã': 983,
#              'bộ': 44,
#              'g': 285,
#              'nguyên': 93,
#              '160668': 6,
#              'h9071512': 8,
#              '06': 143,
#              '07': 81,
#              '150703': 3,
#              '9071512': 4,
#              '151101': 7,
#              '150901': 15,
#              '09': 118,
#              'thành': 241,
#              'bán': 172,
#              'dạng': 51,
#              'phẩm': 211,
#              '5070210': 1,
#              '60': 67,
#              'polypropylene': 619,
#              '5050208': 3,
#              'h8071513': 1,
#              'h8070113': 1,
#              'h8051512': 2,
#              '170901': 1,
#              'máu': 412,
#              'bone': 72,
#              'cầm': 365,
#              'w810t': 5,
#              '5gr': 21,
#              'wax': 120,
#              '24': 375,
#              'c': 246,
#              'lifescan': 1,
#              'johnson': 75,
#              'cho': 32,
#              'sáp': 48,
#              'w31c': 1,
#              'xương': 39,
#              'brasil': 61,
#              'industrial': 3,
#              'lifesciences': 9,
#              'surgispon': 9,
#              'bông': 26,
#              'aegis': 9,
#              'ssp705010': 4,
#              'dia': 12,
#              '80': 47,
#              'ssp8030': 4,
#              'hình': 10,
#              'trụ': 3,
#              'trĩ': 1,
#              'ssp805010': 1,
#              'sponge': 14,
#              'lần': 109,
#              'thấm': 12,
#              'gelatin': 22,
#              '05170502': 7,
#              '70x50x10mm': 32,
#              '7x5x1cm': 2,
#              'oxidized': 9,
#              '06201013': 4,
#              '10x20cm': 19,
#              'regenerate': 1,
#              'regenerated': 8,
#              'cellulose': 10,
#              'x20': 2,
#              '06755013': 1,
#              '5x5cm': 1,
#              'xốp': 30,
#              '1069152': 39,
#              '6pcs': 73,
#              'lyostypt': 32,
#              'aesculap': 23,
#              'sh': 205,
#              'sa': 743,
#              'khv': 20,
#              '5x8cm': 16,
#              'đội': 3,
#              'medtrade': 3,
#              'celox': 3,
#              'quân': 3,
#              'fg08830241': 1,
#              'bột': 25,
#              '35g': 3,
#              'đến': 1,
#              '141499': 2,
#              '02': 98,
#              'cung': 4,
#              'entwicklungs': 2,
#              'gmbh': 129,
#              'cấp': 3,
#              'de': 77,
#              'và': 138,
#              'hfp205': 3,
#              'biocer': 8,
#              'haemocer': 6,
#              'plus': 362,
#              'chưa': 16,
#              'tbyt': 83,
#              'đức': 41,
#              '2019': 125,
#              'hsd': 89,
#              'hfp201': 1,
#              '1g': 5,
#              '2g': 6,
#              'hfp202': 1,
#              'càm': 1,
#              '3g': 7,
#              'hfp203': 1,
#              '5g': 13,
#              'system': 18,
#              'limited': 58,
#              'perclot': 10,
#              'polysaccharide': 13,
#              'clotplus': 10,
#              'hemostatic': 14,
#              'ailen': 10,
#              '15g': 1,
#              'chuẩn': 5,
#              'làm': 20,
#              'catgut': 772,
#              'w115': 1,
#              '150cm': 48,
#              'từ': 53,
#              'ruột': 15,
#              'chrom': 382,
#              'động': 15,
#              'm5': 17,
#              'w441': 4,
#              '30mm': 139,
#              'w448': 2,
#              'm3': 266,
#              'w447': 1,
#              'm4': 78,
#              'w758': 1,
#              'w759': 6,
#              '5c': 37,
#              'jnj': 1,
#              '20mm': 105,
#              'w437': 2,
#              'pln': 1,
#              'w439': 1,
#              'str': 1,
#              'blue': 342,
#              '5ml': 53,
#              'chất': 199,
#              'hàn': 121,
#              '1050044': 21,
#              'histoacryl': 23,
#              '10pc': 8,
#              '1pac': 207,
#              'gắn': 44,
#              '10pcs': 17,
#              '1051260p': 1,
#              'flexible': 1,
#              'chai': 2,
#              's': 544,
#              'tissue': 2,
#              'trns': 2,
#              '1050060': 2,
#              'adhes': 2,
#              '5pcs': 46,
#              '12pcs': 87,
#              '24pcs': 91,
#              '1029754': 24,
#              '24x2': 3,
#              '24pc': 27,
#              '1pa': 34,
#              'bottle': 1,
#              '19611sđk': 1,
#              '220': 1,
#              'vndp': 1,
#              '500ml': 1,
#              'chế': 1,
#              'vn': 1,
#              '03': 135,
#              'softaman': 1,
#              'dp': 2,
#              'khuẩn': 20,
#              'diệt': 1,
#              'hc': 16,
#              'sát': 1,
#              'dermalon': 27,
#              '8886179941': 13,
#              '8886258643': 16,
#              'flexon': 17,
#              'cl915': 30,
#              'gl122': 30,
#              'cl460': 4,
#              'gl123': 31,
#              '8886239389': 15,
#              'steel': 165,
#              '4x45cm': 125,
#              'kv': 19,
#              '40x12': 13,
#              'vp630x': 7,
#              'vp705x': 5,
#              'vp761x': 22,
#              'vp556x': 19,
#              '2xcv': 29,
#              '8886263656': 2,
#              '8886338556': 16,
#              '316': 5,
#              '10x75cm': 31,
#              '10x90cm': 26,
#              '15': 99,
#              '31': 10,
#              '88861756': 1,
#              '41': 10,
#              '88861799': 3,
#              '4254': 7,
#              'sĩ': 91,
#              'thụy': 99,
#              'pga': 461,
#              'r': 172,
#              'assut': 106,
#              'assucryl': 80,
#              '88862586': 4,
#              '43': 4,
#              'brd': 35,
#              's50013': 1,
#              'nhiên': 135,
#              'yds': 42,
#              '2000': 9,
#              'ef': 8,
#              '12f0090r': 1,
#              'cu': 18,
#              '12ho380r': 1,
#              '12ho480r': 1,
#              '12ho330r': 1,
#              '12h0190r': 1,
#              '12f0069r': 1,
#              'norefil': 4,
#              '60b0140r': 1,
#              'pvdf': 19,
#              '60b0190r': 1,
#              'maxon': 25,
#              '88866217': 1,
#              '8886675561': 3,
#              'cl': 9,
#              '122': 5,
#              '123': 6,
#              '915': 4,
#              '460': 1,
#              'gl': 10,
#              'ul': 4,
#              '202': 2,
#              'cl914': 7,
#              '914': 2,
#              '121': 3,
#              '101': 2,
#              's17rh370': 4,
#              's27cd240': 1,
#              's27rh220': 1,
#              's27rh260': 5,
#              's37rh260': 6,
#              '37': 46,
#              'rev': 240,
#              'cutting': 159,
#              '89': 6,
#              '88862393': 6,
#              '8886242009': 1,
#              '2x45cm': 9,
#              '13x12': 1,
#              'gs': 21,
#              'surgicryl': 742,
#              '22': 47,
#              '160827': 1,
#              '910': 564,
#              '160805': 5,
#              'lô160827': 1,
#              '40': 243,
#              'lô160903': 2,
#              'mx': 4,
#              '904': 4,
#              'vp': 47,
#              '523': 2,
#              '706': 4,
#              '709': 4,
#              '889': 6,
#              '522': 3,
#              '556': 3,
#              '581': 5,
#              '630x': 2,
#              '705': 2,
#              '761': 4,
#              'vp523': 2,
#              '556x': 1,
#              'vp580x': 2,
#              '580': 3,
#              'vp581x': 5,
#              '890': 1,
#              '902': 4,
#              'vpf': 2,
#              '720': 1,
#              '710': 2,
#              '36tép': 5,
#              'vp331x': 2,
#              'vp902x': 2,
#              '88862978': 3,
#              '51': 6,
#              '88863229': 4,
#              '8886322931': 6,
#              '8886336951': 3,
#              '88863280': 3,
#              '88863369': 6,
#              '56': 16,
#              '88862981': 3,
#              '88863086': 2,
#              '8886332356': 8,
#              '88863323': 3,
#              '88863324': 4,
#              '8886308656': 6,
#              '88863381': 1,
#              '88863385': 3,
#              'vlocl0124': 1,
#              'loc': 45,
#              'vlocl0316': 6,
#              'vlocm0604': 1,
#              'vlocm1203': 4,
#              'vlocm0614': 6,
#              'vlocm0804': 1,
#              'vloc': 12,
#              'vlocm0315': 2,
#              'vlocl0024': 6,
#              '12tép': 6,
#              'usa': 25,
#              'nxs': 1,
#              'cc00hr26': 1,
#              'luxsutures': 179,
#              'hr': 168,
#              '1918nk': 15,
#              'luxembourg': 150,
#              'ny10dsp062': 3,
#              'dsp': 5,
#              'luxamid': 17,
#              '2x6': 5,
#              'pl01hr40': 14,
#              'luxcryl': 73,
#              'pl20hr26': 9,
#              'plr40ds19': 3,
#              '19mm': 110,
#              'rapid': 147,
#              'pd00hr36': 2,
#              '36mm': 64,
#              'pd30hr26': 3,
#              'pl30hr26': 7,
#              'pd20hr26': 2,
#              'pd40hr22': 3,
#              'pg20hr26': 2,
#              'pg40hr22': 4,
#              '2x25mm': 35,
#              'luxylene': 47,
#              'polypropylen': 16,
#              'pp20hrt25': 5,
#              'hrt': 19,
#              'pp30hr25': 4,
#              '2x20mm': 10,
#              'pp40hr20': 6,
#              '60cm': 320,
#              'pp70dr08': 1,
#              'dr': 3,
#              '2x8mm': 4,
#              'cực': 16,
#              'ptfe60cmgsb60hsyz26': 1,
#              'điện': 16,
#              'cp30m26f63v': 1,
#              'cp20m17f88v': 1,
#              'ptfe60cmgsb88hsyz17': 1,
#              'polyester': 89,
#              'green': 61,
#              '40c351000': 1,
#              '1000m': 13,
#              'cuon': 11,
#              'thuậtkhông': 8,
#              'anh': 30,
#              'pearsalls': 40,
#              'logwood': 33,
#              '15b351000': 1,
#              '15b401000': 1,
#              '3000m': 9,
#              '15b203000': 2,
#              'nươc': 3,
#              'uk': 3,
#              '15b153000': 2,
#              '15b071000': 1,
#              'top': 10,
#              'huaian': 10,
#              'meiyi': 10,
#              'gt044': 17,
#              'tròn': 598,
#              'ptfe60cmgsb60hsyz17': 1,
#              'cp20m17f63vmới': 1,
#              'thời': 148,
#              'adult': 5,
#              'tpw': 5,
#              'tim': 97,
#              'monopolar': 2,
#              'tạm': 5,
#              's60ab': 2,
#              'myocardial': 4,
#              'bipolar': 3,
#              'vf608abb': 2,
#              'epicardial': 1,
#              've60bb': 1,
#              'pediatric': 1,
#              'foc': 101,
#              'ecolene': 21,
#              'ecosyn': 4,
#              'aurolon': 7,
#              'mắt': 198,
#              '6402n': 5,
#              'aurolab': 14,
#              '8482n': 1,
#              '9': 117,
#              '6492n': 2,
#              'aurosilk': 1,
#              '8482vs': 1,
#              'a6108': 1,
#              'polycryl': 3,
#              'a8104': 1,
#              '31680': 10,
#              '2kl40': 10,
#              'acier': 37,
#              'p5': 16,
#              'đặt': 8,
#              'tối': 2,
#              '6002pp': 1,
#              'đa': 161,
#              'thể': 78,
#              'người': 27,
#              'aurolene': 1,
#              'auroring': 1,
#              'corp': 62,
#              '1018b': 1,
#              'specialties': 14,
#              'gồm': 26,
#              '1082b': 1,
#              '311b': 1,
#              '920b': 1,
#              'a7718n': 1,
#              '354nc': 1,
#              'gc': 5,
#              'j1239n': 1,
#              '423nc': 1,
#              'mc': 2,
#              '917nc': 1,
#              'y433n': 1,
#              '23': 27,
#              'co': 182,
#              'polydioxanone': 48,
#              'mga': 3,
#              'liền': 180,
#              '100mm': 7,
#              '19g': 3,
#              'century': 33,
#              'khử': 38,
#              '21': 45,
#              '90mm': 3,
#              '27g': 2,
#              'mp': 57,
#              '15mm': 45,
#              '29': 24,
#              '29g': 34,
#              '38mm': 14,
#              '50mm': 24,
#              'xuât': 4,
#              '23g': 1,
#              'ms': 4,
#              '60mm': 1,
#              'pn': 39,
#              '25g': 1,
#              'c0992038': 16,
#              'hr17': 113,
#              'elec': 11,
#              'gs65': 11,
#              'steelex': 66,
#              '170210': 20,
#              'lô170102': 2,
#              'premilene': 210,
#              '2xdr8': 8,
#              'c2090885': 3,
#              'cv': 193,
#              'c2090880': 2,
#              '2xdr6': 3,
#              'c1048048': 3,
#              'hr30': 41,
#              'safil': 311,
#              '70cm': 756,
#              'c1048095': 7,
#              'lô170604': 8,
#              'cervix': 6,
#              'wht': 1,
#              'tape': 21,
#              '06pcs': 3,
#              '997145': 4,
#              '2xhrn45': 4,
#              '5cm': 23,
#              '50cm': 6,
#              'monosyn': 188,
#              'hr22': 56,
#              'ddp': 42,
#              'c0022014': 16,
#              'c0022015': 20,
#              'drc10': 14,
#              'c0022382': 15,
#              '36pc': 174,
#              'dsmp11': 15,
#              'c0025020': 14,
#              'quick': 71,
#              'c0025032': 7,
#              'dsmp19m': 7,
#              '13x60cm': 45,
#              'silkam': 57,
#              'c0263869': 11,
#              'c0760137': 3,
#              'ds12': 36,
#              'dafilon': 268,
#              'c0932060': 33,
#              'ds19': 83,
#              'c0935204': 36,
#              'ds24': 116,
#              'c0935352': 42,
#              'c0935360': 37,
#              'c0935492': 25,
#              'ds30': 26,
#              'setw': 1,
#              'ele': 1,
#              'stee': 5,
#              'hr13mgs51vbksg': 1,
#              'c0990008': 1,
#              'b3': 1,
#              '2x60cm': 6,
#              '2014hàng': 8,
#              'gs65v': 6,
#              'undy': 82,
#              'qui': 54,
#              'hrt37': 30,
#              'c1046651': 24,
#              'hr26': 177,
#              'c1048042': 36,
#              'c1048058': 14,
#              'hr37s': 41,
#              'c1048096': 16,
#              'c1048220': 12,
#              '45': 88,
#              'c1048236': 10,
#              'c1048557': 34,
#              '40s': 12,
#              'pcs': 12,
#              'hrt26': 15,
#              'c2090342': 15,
#              'c2090901': 15,
#              '2xhr17': 60,
#              'c2090902': 10,
#              '2xhr17cv': 6,
#              '2xhr26': 55,
#              'c2090907': 10,
#              'c2090908': 12,
#              '2xdr10': 42,
#              'c2090915': 22,
#              'rcp': 58,
#              'c2090917': 21,
#              '2xdr12cv': 6,
#              'c2090954': 11,
#              '2xhr13': 12,
#              'hrc48': 19,
#              'ste': 34,
#              'g0617135': 17,
#              'lp': 50,
#              '12pc': 18,
#              'g0617142': 8,
#              'hrc37ss': 19,
#              'set2': 4,
#              'g0617144': 13,
#              '8x75cm2xhr17bcvpf6mlp': 5,
#              'premicron': 125,
#              'w2': 11,
#              'm0027150': 5,
#              'm0027715': 18,
#              '8x75': 13,
#              'mlp': 13,
#              '6pc': 28,
#              '2xhr26cv': 5,
#              'w': 73,
#              'pf6': 19,
#              'm0027766': 13,
#              '8x75cm': 49,
#              'm0027775': 10,
#              'gr': 56,
#              'b0560499': 3,
#              'b0062090': 1,
#              'b0560979': 1,
#              '24ppcs': 3,
#              'b0570753': 15,
#              'b0560502': 5,
#              'b0062103': 4,
#              'b0560430': 11,
#              'b0062073': 1,
#              'b0560480': 4,
#              'b0560421': 9,
#              'b0560413': 6,
#              'b0560138': 1,
#              '161001': 6,
#              'lô170401': 6,
#              'lô170601': 6,
#              'b0530484': 1,
#              'b0032077': 2,
#              'b0530964': 4,
#              'b0032069': 4,
#              'b0530425': 1,
#              'eptfe': 8,
#              'medicalprodukte': 19,
#              'loop': 12,
#              'nằm': 13,
#              '6x3': 5,
#              'chordae': 17,
#              '2xph17': 4,
#              'vỉ': 49,
#              '2xpledgets': 4,
#              'mạch': 105,
#              'santec': 19,
#              '6x3x1': 3,
#              '4x4': 2,
#              '14mm': 2,
#              'pack': 4,
#              'pledges': 3,
#              'ph': 3,
#              'loops': 13,
#              '16mm': 167,
#              '4x5': 1,
#              '18mm': 3,
#              'lô170722': 13,
#              'lô170606': 9,
#              'lô170505': 4,
#              'lô170714': 19,
#              'lô170407': 12,
#              'g1117041': 2,
#              'drm3': 5,
#              '15cm': 66,
#              'drm5': 7,
#              'g1118110': 4,
#              'g1118706': 26,
#              '2xdlm6': 25,
#              'g1118366': 3,
#              'g1118064': 1,
#              'c0977212': 2,
#              'drm6': 5,
#              'g1118170': 1,
#              'g1118030': 1,
#              'hrm8': 1,
#              'g1118161': 1,
#              'g1118714': 1,
#              'g1111434': 2,
#              'blt': 2,
#              'blk': 189,
#              '100mic': 1,
#              'c0935484': 1,
#              'box': 17,
#              ...})

# %%
encode_docs = tokenizer.texts_to_matrix(df.desc)

# %%
encode_docs.shape
# Out:
# (12062, 5057)

# %%
encode_docs[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])
